# %% [markdown]
# ## Practice on how to load directory of excel files

# %%
from langchain_core.documents import Document

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_unstructured import UnstructuredLoader

loader = DirectoryLoader(
    "../data/excel_files",
    glob="**/*.xlsx",
    loader_cls=UnstructuredLoader,
    show_progress=True,
)

docs = loader.load()

print(f"Total Documents: {len(docs)}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]d:\LinkCode\GenAI\YTRAG\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
# Total Documents: 1

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader("../data/excel_files/Sample_xlsx.xlsx")

docs = loader.load()

print(len(docs))
docs[:3]
# Out:
# d:\LinkCode\GenAI\YTRAG\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 1
# [Document(metadata={'source': '../data/excel_files/Sample_xlsx.xlsx', 'file_directory': '../data/excel_files', 'filename': 'Sample_xlsx.xlsx', 'last_modified': '2026-08-01T13:27:20', 'page_name': 'Metrics', 'page_number': 1, 'text_as_html': '<table><tr><td>Week</td><td>Uploads</td><td>Failures</td><td>FailureRate</td></tr><tr><td>W1</td><td>1200</td><td>12</td><td>0.01</td></tr><tr><td>W2</td><td>1560</td><td>18</td><td>0.011538</td></tr><tr><td>W3</td><td>1490</td><td>10</td><td>0.006711</td></tr></table>', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'category': 'Table', 'element_id': '09af432e8e25f3b525ec86aae8a392c8'}, page_content='Week Uploads Failures FailureRate W1 1200 12 0.01 W2 1560 18 0.011538 W3 1490 10 0.006711')]
