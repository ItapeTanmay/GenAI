# %% [markdown]
# ## Practice on how to load PDFs

# %%
from langchain_core.documents import Document

# %%
from langchain_community.document_loaders import DirectoryLoader

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

doc = DirectoryLoader(
    "../data/PDF",
    glob = "**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_document = doc.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Django Interview Questions & Answers \nHere are comprehensive, interview-ready answers organized by topic. \n \nDjango Basics \n1. What is Django? \nDjango is a high-level Python web framework that encourages rapid development and \nclean, pragmatic design. It follows the "batteries-included" philosophy, providing almost \neverything developers need to build web applications out of the box. \n2. Why is Django called a batteries-included framework? \nBecause it comes with a wide range of built-in features right out of the box, including: \n●\u200b ORM (Object-Relational Mapper) \n●\u200b Authentication system \n●\u200b Admin panel \n●\u200b URL routing \n●\u200b Form handling and validation \n●\u200b Session management \n●\u200b Caching \n●\u200b CSRF protection \nYou don\'t need to assemble third-party tools—everything works seamlessly together \nwith consistent design principles. \n3. What are the features of Django? \n●\u200b ORM – write Python instead of SQL to interact with the database \n●\u200b URL routing – clean, regex-based or path-based URL patterns \n●\u200b Template engine – Pythonic HTML templating with inheritance \n●\u200b Forms – automatic form generation and validation'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='●\u200b Authentication – built-in user management \n●\u200b Admin interface – auto-generated admin panel \n●\u200b Migrations – schema version control \n●\u200b Security – CSRF, XSS, SQL injection protection \n●\u200b Internationalization – multi-language support \n●\u200b Caching framework – multiple cache backends \n4. What are the advantages of Django? \n●\u200b Rapid development – pre-built modules speed up common tasks \n●\u200b Secure – protects against common web vulnerabilities \n●\u200b Scalable – used by Instagram, Spotify, and other large platforms \n●\u200b Versatile – can build anything from CMS to social networks \n●\u200b Well-documented – extensive and up-to-date documentation \n●\u200b Large community – abundant third-party packages and support \n5. What is the difference between Django and Flask? \nDjango \nFlask \n"Batteries-included" – full-stack framework \nMicro-framework – minimal core \nBuilt-in ORM, admin, auth, forms \nYou choose your own components \nMore opinionated (Django way) \nFlexible, unopinionated \nHeavier, more features \nLightweight, minimal \nSteeper learning curve \nEasier to get started \nBetter for large, complex applications \nBetter for small APIs or microservices \n6. Explain the MTV architecture.'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='Django follows a modified MVC pattern called Model-Template-View (MTV): \n●\u200b Model – defines data structure and handles database interactions \n●\u200b Template – presentation layer (HTML with Django template tags) – how data is \npresented \n●\u200b View – business logic that processes requests, interacts with models, and \nrenders templates \nThe framework itself acts as the controller, mapping URLs to views and handling the \nrequest-response cycle. \n7. What is the role of manage.py? \nA command-line utility that lets you interact with your Django project. Common \ncommands: \n●\u200b python manage.py runserver – start development server \n●\u200b python manage.py makemigrations – create migration files \n●\u200b python manage.py migrate – apply migrations \n●\u200b python manage.py createsuperuser – create admin user \n●\u200b python manage.py shell – open Django shell \n8. What is the difference between a Django project and a Django app? \nProject \nApp \nA container for apps \nA self-contained module with models, \nviews, and code \nContains settings, not database models \nContains models, views, templates, URLs, \netc. \nOne project per website \nMany apps can exist within a project'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content='Cannot be reused across projects \nCan be reused across multiple projects \n9. How do you create a Django project? \nbash \ndjango-admin startproject myproject \n10. How do you create a Django app? \nbash \npython manage.py startapp myapp \n \nProject Structure \n11. What is the purpose of settings.py? \nContains all configuration for the Django project: \n●\u200b Database configuration \n●\u200b Installed apps list \n●\u200b Middleware \n●\u200b Templates settings \n●\u200b Static/media file settings \n●\u200b Security settings (SECRET_KEY, DEBUG, ALLOWED_HOSTS) \n●\u200b Internationalization settings \n12. What is the purpose of urls.py?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content="Defines URL patterns and maps them to views. It's the routing table for your application \n– when a request comes in, Django matches the URL against these patterns and calls \nthe corresponding view. \n13. What is the purpose of views.py? \nContains the business logic – functions or classes that process HTTP requests, interact \nwith models, and return HTTP responses (usually rendered templates or JSON). \n14. What is the purpose of models.py? \nDefines the data structure for your application. Each model is a Python class that maps \nto a database table. It defines fields, relationships, and methods for data manipulation. \n15. What is the purpose of admin.py? \nRegisters models with Django's built-in admin interface, allowing you to manage data \nthrough a web-based dashboard. You can also customize how models are displayed \nand filtered. \n16. What is the purpose of apps.py? \nContains configuration for the app – defines the app name, default settings, and \nprovides a ready() method for startup code (signals, etc.). \n17. What is the purpose of manage.py? \n(Answered in Q7) \n \nModels & Database"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content="18. What is a Django model? \nA Python class that defines the structure of your database table. Each model class \nmaps to a single database table, and each attribute maps to a database column. \n19. What is ORM? \nObject-Relational Mapper – a technique that lets you interact with your database using \nPython objects instead of writing raw SQL. Django's ORM automatically translates \nPython code to SQL queries. \n20. What are migrations? \nMigrations are Python files that track changes to your models and translate them into \ndatabase schema changes. They allow you to evolve your database schema over time \nwithout losing data. \n21. What is the difference between makemigrations and migrate? \nmakemigrations \nmigrate \nCreates migration files based on changes \nto your models \nApplies the migrations to the database \nDoesn't modify the database \nActually executes the SQL and changes the \nschema \nGenerates Python files in the migrations/ \nfolder \nReads the migration files and runs them \n22. What is the purpose of the __str__() method?"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content='Defines how a model instance is displayed as a string (e.g., in the admin panel, or when \nprinted). It improves readability and debugging. \n23. How do you create a model? \npython \nfrom django.db import models \n \nclass Student(models.Model): \n    name = models.CharField(max_length=100) \n    age = models.IntegerField() \n    email = models.EmailField(unique=True) \n \n    def __str__(self): \n        return self.name \n24. What field types are available in Django models? \n●\u200b CharField – short strings \n●\u200b TextField – long text \n●\u200b IntegerField – integers \n●\u200b BooleanField – True/False \n●\u200b DateField / DateTimeField – dates and times \n●\u200b EmailField – email validation \n●\u200b URLField – URL validation \n●\u200b ForeignKey – one-to-many relationships \n●\u200b ManyToManyField – many-to-many relationships \n●\u200b OneToOneField – one-to-one relationships \n●\u200b DecimalField / FloatField – decimal numbers \n●\u200b FileField / ImageField – file uploads \n25. What is a primary key?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 7}, page_content="A unique identifier for each record in a database table. Django automatically adds an id \nfield as the primary key if you don't specify one. You can use primary_key=True on any \nfield to override this. \n26. What is the Meta class in models? \nAn inner class that provides metadata about the model: \n●\u200b db_table – custom table name \n●\u200b ordering – default ordering for queries \n●\u200b unique_together – composite uniqueness constraints \n●\u200b verbose_name / verbose_name_plural – human-readable names \n●\u200b indexes – custom database indexes \n \nORM Queries \n27. What is a QuerySet? \nA QuerySet is a collection of database query results. It's lazy – the database query is not \nexecuted until the QuerySet is evaluated (e.g., iterated, sliced, or converted to a list). \n28. What is the difference between get() and filter()? \nget() \nfilter() \nReturns a single model instance \nReturns a QuerySet (can contain 0, 1, or \nmany objects) \nRaises DoesNotExist if none found \nReturns empty QuerySet if none found"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 8}, page_content='Raises MultipleObjectsReturned if \nmultiple found \nReturns all matches (no error) \nUse when you expect exactly one result \nUse when you may have zero or multiple \nresults \n29. What is the difference between all() and values()? \nall() \nvalues() \nReturns a QuerySet of model instances \nReturns a QuerySet of dictionaries \nAccess fields via attributes: obj.name \nAccess fields via keys: dict[\'name\'] \nLazy evaluation \nLazy evaluation \nCan access related objects and methods \nOnly returns specified fields (more \nefficient) \n30. How do you insert data using ORM? \npython \n# Method 1: create() \nstudent = Student.objects.create(name="Alice", age=20, \nemail="alice@example.com") \n \n# Method 2: save() \nstudent = Student(name="Bob", age=22) \nstudent.save()'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 9}, page_content='31. How do you update records? \npython \n# Single record update \nstudent = Student.objects.get(id=1) \nstudent.age = 21 \nstudent.save() \n \n# Bulk update \nStudent.objects.filter(age__lt=18).update(status="minor") \n32. How do you delete records? \npython \n# Single record \nstudent = Student.objects.get(id=1) \nstudent.delete() \n \n# Bulk delete \nStudent.objects.filter(age__lt=18).delete() \n33. How do you count records? \npython \ncount = Student.objects.count()           # All records \ncount = Student.objects.filter(age=20).count()  # Filtered \n34. How do you sort records? \npython \n# Ascending \nstudents = Student.objects.order_by(\'name\')'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 10}, page_content="# Descending \nstudents = Student.objects.order_by('-age') \n \n# Multiple fields \nstudents = Student.objects.order_by('age', '-name') \n35. What are ORM lookups? \nField lookups are used with filter(), exclude(), and get() to specify conditions. They \nuse a double-underscore syntax: field__lookuptype=value \n36. Explain contains, icontains, startswith, endswith, gt, \nlt, in, and range. \nLookup \nDescription \nExample \ncontains \nCase-sensitive containment \nname__contains='abc' \nicontains \nCase-insensitive containment \nname__icontains='abc' \nstartswith \nCase-sensitive prefix \nname__startswith='A' \nendswith \nCase-sensitive suffix \nname__endswith='z' \ngt \nGreater than \nage__gt=18 \nlt \nLess than \nage__lt=18 \ngte / lte \nGreater/less than or equal \nage__gte=18"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 11}, page_content="in \nIn a list \nage__in=[18, 20, 22] \nrange \nBetween two values \nage__range=(18, 25) \nexact \nExact match (default) \nname__exact='Alice' \niexact \nCase-insensitive exact \nname__iexact='alice' \n \nViews \n37. What is a view? \nA view is a Python function or class that receives an HTTP request and returns an HTTP \nresponse. It contains the business logic for your application – processing data, \ninteracting with models, and rendering templates. \n38. What is the difference between Function-Based Views (FBVs) and \nClass-Based Views (CBVs)? \nFunction-Based Views (FBVs) \nClass-Based Views (CBVs) \nSimple, explicit, easy to understand \nMore structured, reusable \nUse conditional branching for HTTP \nmethods \nUse separate methods for each HTTP \nmethod \nLess code for simple views \nMore code upfront, but less repetition for \ncommon patterns"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 12}, page_content='Harder to extend \nEasy to extend via inheritance \nBetter for beginners \nBetter for complex, repetitive patterns \n39. What are HTTP methods? \nThe standard HTTP verbs used to indicate the desired action on a resource: \n●\u200b GET – retrieve data \n●\u200b POST – submit/create data \n●\u200b PUT – update/replace a resource \n●\u200b PATCH – partial update \n●\u200b DELETE – delete a resource \n40. What is the difference between GET and POST? \nGET \nPOST \nAppends data to URL (query string) \nSends data in request body \nVisible in browser history \nNot visible in URL \nLimited data size \nNo size limit \nCan be cached and bookmarked \nNot cached or bookmarked \nShould be idempotent (no side effects) \nChanges server state \nUse for search, filtering, reading \nUse for forms, login, data submission \n41. How do you pass data from a view to a template?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 13}, page_content="Using the context dictionary in the render() function: \npython \ndef student_list(request): \n    students = Student.objects.all() \n    context = { \n        'students': students, \n        'title': 'Student Directory', \n        'count': students.count() \n    } \n    return render(request, 'students/list.html', context) \n42. What is render()? \nA shortcut function that: \n1.\u200b Loads a template \n2.\u200b Renders it with the provided context \n3.\u200b Returns an HttpResponse object with the rendered content \npython \nfrom django.shortcuts import render \nreturn render(request, 'template.html', context) \n43. What is redirect()? \nA shortcut that returns an HttpResponseRedirect to a specified URL: \npython \nfrom django.shortcuts import redirect \nreturn redirect('home')          # by URL name \nreturn redirect('/dashboard/')   # by path \nreturn redirect('student_detail', student_id=1)  # with parameters"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 14}, page_content="URL Routing \n44. What is URL routing? \nThe process of mapping incoming URLs to the appropriate views. Django matches the \nURL path against defined patterns and calls the corresponding view function or class. \n45. What is the path() function? \nUsed in urls.py to define URL patterns: \npython \nfrom django.urls import path \nfrom . import views \n \nurlpatterns = [ \n    path('students/', views.student_list, name='student_list'), \n    path('students/<int:id>/', views.student_detail, name='student_detail'), \n] \n46. What is include()? \nUsed to include other URL configurations – keeps your project organized by delegating \nURL routing to individual apps: \npython \nfrom django.urls import include, path \n \nurlpatterns = [ \n    path('students/', include('students.urls')), \n    path('teachers/', include('teachers.urls')), \n]"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 15}, page_content='47. What are URL parameters? \nDynamic parts of a URL that capture values and pass them to views: \n●\u200b <int:id> – captures an integer \n●\u200b <str:name> – captures a string \n●\u200b <slug:slug> – captures a slug \n●\u200b <uuid:uuid> – captures a UUID \n●\u200b <path:path> – captures a full path \n48. How do you reverse URLs? \nUsing the reverse() function or the {% url %} template tag: \npython \n# In views \nfrom django.urls import reverse \nurl = reverse(\'student_detail\', args=[1])  # \'/students/1/\' \n \n# In templates \n<a href="{% url \'student_detail\' student.id %}">View</a> \n \nTemplates \n49. What is the Django template engine? \nDjango\'s built-in templating system that allows you to generate HTML dynamically. It \nuses its own language with template tags ({% %}) and variables ({{ }}). \n50. What are template tags? \nSpecial syntax ({% ... %}) that performs logic in templates:'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 16}, page_content='●\u200b {% for %} – loops \n●\u200b {% if %} – conditionals \n●\u200b {% block %} – defines a block for inheritance \n●\u200b {% extends %} – inherits from a parent template \n●\u200b {% include %} – includes another template \n●\u200b {% url %} – generates URLs \n●\u200b {% load %} – loads custom template tags \n51. What are template filters? \nModify variables for display using the pipe (|) syntax: \n●\u200b {{ name|upper }} – uppercase \n●\u200b {{ date|date:"Y-m-d" }} – format date \n●\u200b {{ text|truncatewords:30 }} – truncate \n●\u200b {{ value|default:"N/A" }} – default value \n●\u200b {{ list|join:", " }} – join list \n52. How do you write loops in templates? \ndjango \n{% for student in students %} \n    <li>{{ student.name }} - {{ student.age }}</li> \n{% empty %} \n    <li>No students found</li> \n{% endfor %} \n53. How do you write conditions in templates? \ndjango \n{% if student.age >= 18 %} \n    <p>Adult</p> \n{% elif student.age >= 13 %} \n    <p>Teenager</p> \n{% else %}'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 17}, page_content='<p>Child</p> \n{% endif %} \n54. What is template inheritance? \nA powerful feature that allows you to create a base template with common structure \n(header, footer, navigation) and extend it in child templates, overriding specific blocks. \n55. What are {% extends %} and {% block %}? \n●\u200b {% extends "base.html" %} – tells Django to use base.html as the parent \ntemplate \n●\u200b {% block content %} – defines a region that child templates can override \nbase.html: \ndjango \n<html> \n<head><title>{% block title %}My Site{% endblock %}</title></head> \n<body> \n    {% block content %}{% endblock %} \n</body> \n</html> \nchild.html: \ndjango \n{% extends "base.html" %} \n{% block title %}Student List{% endblock %} \n{% block content %} \n    <h1>Students</h1> \n    <!-- content here --> \n{% endblock %}'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 18}, page_content='Forms \n56. What is a Django Form? \nA Python class that handles form rendering, validation, and data processing. It reduces \nboilerplate and provides built-in security. \n57. What is a ModelForm? \nA specialized form that automatically generates fields from a Django model: \npython \nfrom django.forms import ModelForm \nfrom .models import Student \n \nclass StudentForm(ModelForm): \n    class Meta: \n        model = Student \n        fields = [\'name\', \'age\', \'email\'] \n58. What is form validation? \nThe process of ensuring submitted data meets the required criteria. Django provides: \n●\u200b Field-level validation – via clean_<fieldname>() methods \n●\u200b Form-level validation – via clean() method \n●\u200b Built-in validators – on field definitions \n59. How do you display validation errors? \ndjango \n{% if form.errors %} \n    <div class="errors"> \n        {% for field, errors in form.errors.items %}'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 19}, page_content='{% for error in errors %} \n                <p>{{ error }}</p> \n            {% endfor %} \n        {% endfor %} \n    </div> \n{% endif %} \n \n{% for field in form %} \n    {{ field.label_tag }} \n    {{ field }} \n    {{ field.errors }} \n{% endfor %} \n60. What is CSRF protection? \nCross-Site Request Forgery protection prevents malicious websites from submitting \nunauthorized requests. Django includes CSRF tokens in forms: \ndjango \n<form method="post"> \n    {% csrf_token %} \n    {{ form }} \n    <button type="submit">Submit</button> \n</form> \n \nAdmin Panel \n61. What is the Django Admin Panel? \nAn auto-generated, feature-rich administrative interface for managing your application\'s \ndata. It reads your models and provides a CRUD (Create, Read, Update, Delete) interface. \n62. How do you register a model in the admin?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 20}, page_content="In admin.py: \npython \nfrom django.contrib import admin \nfrom .models import Student \n \nadmin.site.register(Student) \n63. How do you create a superuser? \nbash \npython manage.py createsuperuser \n64. How do you customize the admin panel? \npython \n@admin.register(Student) \nclass StudentAdmin(admin.ModelAdmin): \n    list_display = ['name', 'age', 'email', 'created_at'] \n    list_filter = ['age', 'created_at'] \n    search_fields = ['name', 'email'] \n    ordering = ['-created_at'] \n    fieldsets = ( \n        ('Personal Info', {'fields': ('name', 'age', 'email')}), \n        ('Timestamps', {'fields': ('created_at', 'updated_at')}), \n    ) \n \nAuthentication \n65. What is authentication?"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 21}, page_content="The process of verifying identity – confirming that a user is who they claim to be (login). \n66. What is authorization? \nThe process of determining permissions – what an authenticated user is allowed to do. \n67. How do you create a user? \npython \nfrom django.contrib.auth.models import User \n \n# Create user with password (hashed automatically) \nuser = User.objects.create_user('username', 'email@example.com', \n'password123') \n68. How do you log in a user? \npython \nfrom django.contrib.auth import authenticate, login \n \ndef login_view(request): \n    user = authenticate(request, username='alice', password='secret') \n    if user is not None: \n        login(request, user) \n        return redirect('home') \n69. How do you log out a user? \npython \nfrom django.contrib.auth import logout \n \ndef logout_view(request): \n    logout(request)"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 22}, page_content="return redirect('home') \n70. What is login_required? \nA decorator that restricts access to views – only authenticated users can access them: \npython \nfrom django.contrib.auth.decorators import login_required \n \n@login_required \ndef profile_view(request): \n    return render(request, 'profile.html') \n \nStatic & Media Files \n71. What are static files? \nAssets that don't change and are not user-uploaded: CSS, JavaScript, images, fonts. \n72. What are media files? \nUser-uploaded content: profile pictures, documents, videos. \n73. What is the difference between static and media files? \nStatic Files \nMedia Files \nPart of the application codebase \nUser-generated content"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 23}, page_content="Same for all users \nUnique per user \nCollected with collectstatic \nStored in MEDIA_ROOT \nUsually in version control \nNot in version control \n74. What are STATIC_URL and MEDIA_URL? \nURL prefixes used to serve files: \n●\u200b STATIC_URL = '/static/' – the URL for static files \n●\u200b MEDIA_URL = '/media/' – the URL for media files \n75. What are STATIC_ROOT and MEDIA_ROOT? \nFilesystem paths: \n●\u200b STATIC_ROOT – directory where collectstatic collects all static files for \nproduction \n●\u200b MEDIA_ROOT – absolute filesystem path where user-uploaded files are stored \n \nRelationships \n76. What is ForeignKey? \nA one-to-many relationship – one model has many instances of another: \npython \nclass Author(models.Model): \n    name = models.CharField(max_length=100)"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 24}, page_content='class Book(models.Model): \n    title = models.CharField(max_length=200) \n    author = models.ForeignKey(Author, on_delete=models.CASCADE) \n77. What is OneToOneField? \nA one-to-one relationship – each record in one model relates to exactly one record in \nanother: \npython \nclass UserProfile(models.Model): \n    user = models.OneToOneField(User, on_delete=models.CASCADE) \n    bio = models.TextField() \n78. What is ManyToManyField? \nA many-to-many relationship – records from one model can relate to many records in \nanother, and vice versa: \npython \nclass Student(models.Model): \n    name = models.CharField(max_length=100) \n \nclass Course(models.Model): \n    name = models.CharField(max_length=100) \n    students = models.ManyToManyField(Student) \n79. Explain model relationships with examples. \nRelationship \nExample \nDjango Field'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 25}, page_content="One-to-Many \nAuthor → Books \nForeignKey \nOne-to-One \nUser → Profile \nOneToOneField \nMany-to-Many \nStudents ↔ Courses \nManyToManyField \n \nMiddleware \n80. What is middleware? \nMiddleware is a framework of hooks into Django's request/response processing. It's a \nlightweight plugin that processes each request and response globally. \n81. Name some built-in middleware. \n●\u200b AuthenticationMiddleware – associates users with requests \n●\u200b SessionMiddleware – enables session support \n●\u200b CsrfViewMiddleware – CSRF protection \n●\u200b SecurityMiddleware – security headers \n●\u200b CommonMiddleware – URL rewriting, etags \n●\u200b MessageMiddleware – message framework \n●\u200b XFrameOptionsMiddleware – clickjacking protection \n82. How does middleware work? \nMiddleware is processed in a chain: \n1.\u200b Request phase – middleware processes the request in the order they're listed \n(top to bottom) \n2.\u200b View phase – the view is called \n3.\u200b Response phase – middleware processes the response in reverse order (bottom \nto top)"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 26}, page_content="Each middleware can: \n●\u200b Process the request before it reaches the view \n●\u200b Process the response before it's sent to the client \n●\u200b Short-circuit the request/response cycle \n \nSessions & Cookies \n83. What is a session? \nA server-side mechanism to store user-specific data across multiple requests. Sessions \nare identified by a session ID stored in a cookie. \n84. What is a cookie? \nA small piece of data stored on the client's browser. Cookies are sent with every request \nto the same domain. \n85. What is the difference between sessions and cookies? \nSessions \nCookies \nStored server-side \nStored client-side (browser) \nMore secure (data not exposed) \nLess secure (data visible to user) \nCan store large amounts of data \nLimited size (~4KB) \nData persists until session expires \nCan be set to expire at a specific time"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 27}, page_content="Uses a session ID cookie for identification \nStores data directly \n \nSecurity \n86. What is CSRF? \nCross-Site Request Forgery – an attack where a malicious website tricks a user into \nmaking an unwanted request to a website where they're authenticated. Django prevents \nthis with CSRF tokens. \n87. What is XSS? \nCross-Site Scripting – an attack where malicious scripts are injected into web pages \nviewed by other users. Django's template engine automatically escapes output to \nprevent XSS. \n88. What is SQL Injection? \nAn attack where malicious SQL queries are injected through form inputs. Django's ORM \nuses parameterized queries, which makes SQL injection impossible when using the \nORM correctly. \n89. How does Django prevent SQL Injection? \n●\u200b ORM uses parameterized queries – user input is treated as data, not executable \ncode \n●\u200b Raw SQL should use cursor.execute(sql, params) with parameter binding \n●\u200b Never use string concatenation for SQL queries \n \nDjango REST Framework (Basic)"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 28}, page_content="90. What is Django REST Framework? \nA powerful and flexible toolkit for building Web APIs in Django. It provides: \n●\u200b Serializers for data conversion \n●\u200b Browsable API \n●\u200b Authentication and permissions \n●\u200b ViewSets and Routers \n91. What is a serializer? \nSerializers convert complex data (QuerySets, model instances) to Python datatypes that \ncan be rendered into JSON, XML, or other formats. They also handle deserialization \n(validating and saving incoming data). \n92. What is JSON? \nJavaScript Object Notation – a lightweight data-interchange format that is \nhuman-readable and easy for machines to parse. It's the most common format for REST \nAPIs. \n93. What is an API? \nApplication Programming Interface – a set of rules and protocols that allows different \nsoftware applications to communicate with each other. \n94. What are RESTful APIs? \nAPIs that follow REST (Representational State Transfer) principles: \n●\u200b Stateless \n●\u200b Resource-based (using URLs) \n●\u200b HTTP methods (GET, POST, PUT, DELETE) \n●\u200b JSON/XML responses \n●\u200b HATEOAS (hypermedia)"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 29}, page_content="95. What is the difference between PUT and PATCH? \nPUT \nPATCH \nReplaces the entire resource \nPartially updates a resource \nSends the complete resource data \nSends only the fields to update \nIdempotent (same request → same result) \nNot necessarily idempotent \nIf a field is missing, it's set to default/null \nMissing fields are left unchanged \n \nDeployment \n96. What is WSGI? \nWeb Server Gateway Interface – a standard interface between web servers and Python \nweb applications. Django uses WSGI for synchronous (traditional) deployment. \n97. What is ASGI? \nAsynchronous Server Gateway Interface – the successor to WSGI that supports \nasynchronous operations. Django supports ASGI for WebSockets, long-polling, and \nother async features. \n98. What is the default database in Django? \nSQLite (lightweight, file-based database). \n99. Which databases does Django support?"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 30}, page_content='●\u200b Default: SQLite \n●\u200b Official support: PostgreSQL, MySQL, Oracle \n●\u200b Third-party: MongoDB (via Djongo), CockroachDB, and others \n100. How do you deploy a Django application? \nCommon approaches: \n1.\u200b Traditional hosting – Apache/nginx + WSGI (Gunicorn, uWSGI) \n2.\u200b Platform as a Service – Heroku, PythonAnywhere, AWS Elastic Beanstalk \n3.\u200b Containerized – Docker + Kubernetes \n4.\u200b Serverless – AWS Lambda (with Zappa) \nSteps typically include: \n●\u200b Set DEBUG = False \n●\u200b Configure ALLOWED_HOSTS \n●\u200b Run collectstatic \n●\u200b Set up a production database \n●\u200b Use environment variables for secrets \n●\u200b Configure a reverse proxy (nginx) and WSGI server (Gunicorn) \n \nGit & Project-Based Questions \n101. Explain your Django project. \nStructure your answer: \n●\u200b Problem – what was the project about? \n●\u200b Solution – how did Django help? \n●\u200b Key features – what did you build? \n●\u200b Technical choices – why Django? Why that database? \n●\u200b Challenges – what was difficult and how did you solve it? \n●\u200b Outcome – what did you learn?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 31}, page_content='102. Which database did you use and why? \n●\u200b SQLite – for development (lightweight, no setup) \n●\u200b PostgreSQL – for production (robust, supports advanced features like JSON, \nfull-text search) \n●\u200b MySQL – if the organization already uses it \n103. What challenges did you face during development? \nCommon challenges and how to present them: \n●\u200b Performance issues – optimized queries with select_related() and \nprefetch_related() \n●\u200b Authentication – implemented JWT or session-based auth \n●\u200b File uploads – handled large files with chunked uploads \n●\u200b Deployment – configured environment variables and static files \n104. How did you use Git in your project? \n●\u200b Feature branches: feature/login, feature/dashboard \n●\u200b Commit messages: descriptive, following conventional commits \n●\u200b Pull requests: code reviews before merging \n●\u200b Tagging: version tags (v1.0.0) \n105. How do you debug Django applications? \n●\u200b print() / pprint() for quick checks \n●\u200b import pdb; pdb.set_trace() for interactive debugging \n●\u200b Django Debug Toolbar – shows SQL queries, performance metrics \n●\u200b logging module for production logging \n●\u200b django-extensions – shell_plus for better shell \n106. Have you worked with REST APIs?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'file_path': '..\\data\\PDF\\Django Interview Questions & Answers.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Django Interview Questions & Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 32}, page_content='If yes: Mention DRF, serializers, authentication, API versioning, documentation \n(Swagger/DRF-YASG).\u200b\nIf no: Mention understanding of REST concepts and willingness to learn. \n107. What is the request-response lifecycle in Django? \n1.\u200b Browser sends HTTP request \n2.\u200b Web server (nginx/Apache) receives it \n3.\u200b WSGI/ASGI server (Gunicorn/Uvicorn) passes it to Django \n4.\u200b Middleware processes the request \n5.\u200b URL resolver finds the matching view \n6.\u200b View executes business logic (may query the database via ORM) \n7.\u200b View renders a template or returns JSON \n8.\u200b Response goes back through middleware (in reverse) \n9.\u200b Web server sends the response to the browser \n108. How do you optimize Django queries? \n●\u200b Use select_related() for foreign key relationships (JOINs) \n●\u200b Use prefetch_related() for many-to-many and reverse foreign keys \n●\u200b Use only() and defer() to select only needed fields \n●\u200b Use values() or values_list() for specific fields \n●\u200b Add database indexes with db_index=True or Meta.indexes \n●\u200b Use count() instead of len(queryset) \n●\u200b Use exists() to check existence without fetching objects \n109. What are the common Django commands you use? \nCommand \nPurpose \nrunserver \nStart development server \nmakemigrations \nCreate migration files'),
# ...
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 110}, page_content='13. Can child access private variables? \nNo, not directly. Private variables (with __) are name‑mangled to _Parent__var, so they \nare not accessible in the child under the same name. However, the child can still access \nthem using the mangled name (not recommended). Protected variables (_var) are \naccessible. \n14. Real‑world example of inheritance. \npython \nclass Vehicle: \n    def __init__(self, make, model): \n        self.make = make \n        self.model = model \n \n    def start(self): \n        return "Vehicle starting" \n \nclass Car(Vehicle): \n    def __init__(self, make, model, doors): \n        super().__init__(make, model) \n        self.doors = doors \n \n    def start(self): \n        return "Car engine starts with a key" \n15. Design a vehicle management system using inheritance. \npython \nclass Vehicle: \n    def __init__(self, reg_no, color): \n        self.reg_no = reg_no \n        self.color = color \n \n    def move(self): \n        return "Vehicle moves"'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 111}, page_content='class Car(Vehicle): \n    def move(self): \n        return "Car drives on roads" \n \nclass Bike(Vehicle): \n    def move(self): \n        return "Bike rides on two wheels" \n \nclass Truck(Vehicle): \n    def __init__(self, reg_no, color, load_capacity): \n        super().__init__(reg_no, color) \n        self.load_capacity = load_capacity \n \n    def move(self): \n        return "Truck carries heavy loads" \n \n# Usage \nvehicles = [Car("KA-01", "Red"), Bike("KA-02", "Blue"), Truck("KA-03", \n"White", 5000)] \nfor v in vehicles: \n    print(v.move()) \n \nOOP - POLYMORPHISM \n1. What is polymorphism? \nThe ability of objects of different classes to respond to the same method call in their \nown specific way. It means "many forms" – you can treat different objects through a \ncommon interface. \n2. Why is polymorphism useful? \n●\u200b Code reusability – write generic functions that work with any object that supports \na given method.'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 112}, page_content="●\u200b Flexibility – add new classes without changing existing code (Open/Closed \nPrinciple). \n●\u200b Simplifies APIs – client code uses a uniform interface regardless of the \nunderlying type. \n3. What is method overriding? \nWhen a child class provides a specific implementation of a method that is already \ndefined in its parent. The child's version overrides the parent's. This is a form of runtime \npolymorphism. \n4. What is method overloading? \nHaving multiple methods with the same name but different parameters (number or \ntype) within the same class. It's compile‑time polymorphism in languages like \nJava/C++. \n5. Does Python support method overloading? \nNot natively. Python does not allow multiple methods with the same name in the same \nscope (the last one wins). However, you can simulate it using: \n●\u200b Default arguments (def add(a, b=0)). \n●\u200b Variable arguments (*args, **kwargs). \n●\u200b functools.singledispatch for single‑dispatch generic functions. \n6. Difference between overriding and overloading? \nOverriding \nOverloading \nRedefines a method in a subclass with the \nsame signature. \nMultiple methods in the same class with \nsame name but different signatures."),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 113}, page_content='Runtime polymorphism. \nCompile‑time (static) polymorphism. \nUses inheritance. \nNo inheritance required. \nPython supports it natively. \nPython does not support it natively. \n7. What is duck typing? \nA programming style where the type of an object is determined by its methods and \nattributes (what it can do), not by its class. If it walks like a duck and quacks like a duck, \nit\'s a duck. In Python, you call methods without checking types – if the object supports \nthe method, it works; otherwise, it fails at runtime. \n8. Real‑world example of polymorphism. \npython \nclass Cat: \n    def sound(self): \n        return "Meow" \n \nclass Dog: \n    def sound(self): \n        return "Bark" \n \ndef make_sound(animal): \n    print(animal.sound()) \n \nmake_sound(Cat())  # Meow \nmake_sound(Dog())  # Bark \nBoth Cat and Dog respond to sound(), allowing the function to work with any object that \nhas that method. \n9. Why use polymorphism in large projects?'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 114}, page_content='●\u200b Maintainability – new subclasses can be added without modifying existing \nfunctions. \n●\u200b Testability – mock objects can replace real ones for unit testing. \n●\u200b Scalability – codebases grow without needing to rewrite core logic. \n●\u200b Design patterns – many patterns (Strategy, Command) rely on polymorphism. \n10. Design a payment gateway using polymorphism. \npython \nclass Payment: \n    def pay(self, amount): \n        pass \n \nclass CreditCard(Payment): \n    def pay(self, amount): \n        return f"Paid {amount} via Credit Card" \n \nclass PayPal(Payment): \n    def pay(self, amount): \n        return f"Paid {amount} via PayPal" \n \nclass BankTransfer(Payment): \n    def pay(self, amount): \n        return f"Paid {amount} via Bank Transfer" \n \ndef process_payment(payment_method, amount): \n    print(payment_method.pay(amount)) \n \n# Usage \nprocess_payment(CreditCard(), 100) \nprocess_payment(PayPal(), 200) \nprocess_payment(BankTransfer(), 150) \nNew payment methods can be added without changing process_payment. \n \nOOP - ABSTRACTION'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 115}, page_content="1. What is abstraction? \nThe concept of hiding complex implementation details and exposing only the essential \nfeatures (interface) to the user. It reduces complexity by providing a clear, high‑level API, \nignoring irrelevant internals. \n2. Why is abstraction needed? \n●\u200b Simplifies usage – users interact with a clean interface. \n●\u200b Reduces complexity – internal complexity is hidden. \n●\u200b Promotes maintainability – implementation can change without affecting clients. \n●\u200b Enforces a contract – ensures subclasses implement required methods. \n3. Difference between abstraction and encapsulation? \nAbstraction \nEncapsulation \nFocuses on what an object does \n(interface). \nFocuses on how it does it (internal state \nand hiding). \nProvides a simplified view. \nBundles data and methods; restricts \naccess. \nAchieved via abstract classes/interfaces. \nAchieved via private/protected members \nand getters/setters. \nExample: Vehicle has start() – you don't \nknow how. \nExample: __engine is private; you \nmanipulate via start(). \n4. What is an abstract class?"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 116}, page_content="A class that cannot be instantiated and is intended to be a base for other classes. It \nmay contain abstract methods (declared but not implemented) that subclasses must \nimplement. In Python, use the abc module. \n5. Why can't abstract classes be instantiated? \nThey are incomplete – they may have abstract methods with no implementation. \nInstantiating them would lead to invalid objects missing required behavior. The \nlanguage prevents that. \n6. What is the ABC module? \nThe abc (Abstract Base Classes) module in Python provides infrastructure for defining \nabstract classes and abstract methods. You inherit from ABC and use @abstractmethod \ndecorator. \n7. What is @abstractmethod? \nA decorator that marks a method as abstract – meaning it has no implementation in the \nabstract class. Any concrete subclass must override this method. If a subclass does not \nimplement all abstract methods, it also becomes abstract. \n8. Can an abstract class have normal methods? \nYes. An abstract class can contain concrete (fully implemented) methods that are \ninherited by subclasses. This provides shared functionality while still enforcing abstract \nmethod implementation. \n9. Real‑world example of abstraction. \npython \nfrom abc import ABC, abstractmethod \n \nclass PaymentProcessor(ABC):"),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 117}, page_content='@abstractmethod \n    def process_payment(self, amount): \n        pass \n \n    def log_transaction(self, amount): \n        print(f"Logging transaction for {amount}") \n \nclass CreditCardProcessor(PaymentProcessor): \n    def process_payment(self, amount): \n        return f"Processing {amount} via credit card" \n \nclass PayPalProcessor(PaymentProcessor): \n    def process_payment(self, amount): \n        return f"Processing {amount} via PayPal" \nPaymentProcessor defines the abstraction – you don\'t need to know how each \nprocessor works, just that they implement process_payment. \n10. Design an online banking system using abstraction. \npython \nfrom abc import ABC, abstractmethod \n \nclass BankAccount(ABC): \n    def __init__(self, account_number, balance=0): \n        self.account_number = account_number \n        self.balance = balance \n \n    @abstractmethod \n    def deposit(self, amount): \n        pass \n \n    @abstractmethod \n    def withdraw(self, amount): \n        pass \n \n    @abstractmethod \n    def get_account_type(self): \n        pass'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 118}, page_content='def check_balance(self): \n        return self.balance \n \nclass SavingsAccount(BankAccount): \n    def deposit(self, amount): \n        self.balance += amount \n        return f"Deposited {amount} to Savings" \n \n    def withdraw(self, amount): \n        if amount > self.balance: \n            raise ValueError("Insufficient balance") \n        self.balance -= amount \n        return f"Withdrew {amount} from Savings" \n \n    def get_account_type(self): \n        return "Savings" \n \nclass CurrentAccount(BankAccount): \n    def deposit(self, amount): \n        self.balance += amount \n        return f"Deposited {amount} to Current" \n \n    def withdraw(self, amount): \n        if amount > self.balance + 1000:  # Overdraft limit \n            raise ValueError("Overdraft limit exceeded") \n        self.balance -= amount \n        return f"Withdrew {amount} from Current" \n \n    def get_account_type(self): \n        return "Current" \n \n# Usage \naccounts = [SavingsAccount("SA001", 5000), CurrentAccount("CA001", 2000)] \nfor acc in accounts: \n    print(acc.deposit(1000)) \n    print(acc.get_account_type()) \n    print(acc.check_balance())'),
#  Document(metadata={'producer': 'Skia/PDF m152 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'file_path': '..\\data\\PDF\\Python Question Bank Answers.pdf', 'total_pages': 120, 'format': 'PDF 1.4', 'title': 'Python Question Bank Answers', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 119}, page_content='The abstract class BankAccount defines a clear contract (interface) – all account types \nmust implement deposit, withdraw, and get_account_type, while sharing common \nattributes and the check_balance method. \n \n🎯 Interview Pro‑Tips for this section: \n●\u200b Inheritance Q6 – always mention that super() follows MRO, not just parent – \ncrucial for multiple inheritance. \n●\u200b Polymorphism Q7 – duck typing is a Python signature trait; give the "call method \nwithout type checks" example. \n●\u200b Abstraction Q3 – emphasize the difference: encapsulation is about hiding, \nabstraction is about simplifying. \n●\u200b Abstraction Q6–7 – show familiarity with the abc module – it shows you know \nPython-specific tools.')]
